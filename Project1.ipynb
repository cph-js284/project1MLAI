# %% [markdown]
# This is the first project excercise in ML-AI course soft2019spring

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as date
# %matplotlib inline

# %%
data = pd.read_json("users.json")

# %% [markdown]
# Part 1.1: Data preprocessing
# Plotting the data, time on the x-axis and points on the y-axis

# %%
data
# Out:
#                                                   about       created error  \
# 0                                                   NaN  1.510266e+09   NaN
# 1                             Ruby, Open Source, Devops  1.325548e+09   NaN
# 2                                                   NaN  1.459331e+09   NaN
# 3     [ my public key: https:&#x2F;&#x2F;keybase.io&...  1.379698e+09   NaN
# 4     Email: ejstronge@gmail.com\nGithub: https:&#x2...  1.355740e+09   NaN
# 5                                                   NaN  1.276201e+09   NaN
# 6                                                   NaN  1.382222e+09   NaN
# 7                                                   NaN  1.330724e+09   NaN
# 8                                                   NaN  1.475393e+09   NaN
# 9                            github.com&#x2F;allcentury  1.389810e+09   NaN
# 10              metaleap.net | github.com&#x2F;metaleap  1.200513e+09   NaN
# ...

# %%
#xs =  2019 - (1970 +  data.created / (60*60*24*365))
#ys = data.karma / data.submitted
xs=data.created
ys=data.karma / data.submitted

# %%
#data.plot.scatter(xs,ys) <- godt så, det virker ikke
#Jeg synes ikke denne data ser rigtigt ud - det er x-asken der forvirer mig
#den eneste mulige forklaring -jeg kan komme på - på at tallene i created-kolonnen er så store er:
# at det er en tidsangivelse på hvor mange sekunder der er gået siden 1970.01.01. Men selv hvis det er det
#burde det så ikke være ligegyldigt, der er jo ens for alle brugerne?

plt.plot(xs,ys, 'bo')

# %%
User1 = data['id'].values[2]
User1Created = data['id'].values[2]
User1Karma = data['karma'].values[2]
User1Submits = data['submitted'].values[2]

User2 = data['id'].values[7000]
User2Created = data['id'].values[7000]
User2Karma = data['karma'].values[7000]
User2Submits = data['submitted'].values[7000]

def f(x):
    return  x + 0

# %%
xsPredict = f(xs)

# %%
plt.plot(xs,ys, 'bo', xsPredict)
